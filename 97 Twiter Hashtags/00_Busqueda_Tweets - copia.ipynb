# %%
import time 
import json # manipulación de archivos json
import os # funciones del sistema operativo
import logging # escribir logs
import requests # requests de páginas
from threading import Thread
from http.client import IncompleteRead
from twython import TwythonStreamer # Obtener los tweets en tiempo real
from twython import Twython # Generar conexión con Twitter mediante Twithon

# %% [markdown]
# ## Se accederán a los tweets en tiempo real mediante la API Twython
# ## Se contará con un archivo config en formato JSON que contendrá los parámetros relevantes para las conexiones y búsquedas

# %%
"""" 
Declaro una clase Authentication cuyas instancias permitirán leer el archivo config para obtener los parámetros
de conexión y de búsqueda de contenidos en tweets, como así también de almacenamiento de archivos json.
"""
class Authentication:
    
    """
    Función que me permite recorrer un archivo JSON, en donde iremos recorriendo línea por línea para obtener
    el contenido de cada atributo y devolverlos como resultado
    """
    def read_config_file(self, filename):
        with open(filename, "r") as f:
            s = f.read()
        d = json.loads(s)
        APP_KEY = d["APP_KEY"]
        APP_SECRET = d["APP_SECRET"]
        TERMS_FILE = d["TERMS_FILE"]
        STORAGE_PATH = d["STORAGE_PATH"]
        return APP_KEY, APP_SECRET, TERMS_FILE, STORAGE_PATH
    
    """
    Obtengo los accesos mediante los keys de Twitter
    """
    def get_oauth_link(self, APP_KEY, APP_SECRET):
        twitter = Twython(APP_KEY, APP_SECRET) # genero un objeto de la API
        auth = twitter.get_authentication_tokens() # obtengo los tokens de autenticación
        # guardo los valores obtenidos en variables
        OAUTH_TOKEN = auth['oauth_token']
        OAUTH_TOKEN_SECRET = auth['oauth_token_secret']
        url = (auth['auth_url'])
        # genero un requests a la url obtenida
        r = requests.get(url)
        # muestro el link de twitter para que genere el pin de autorización a la app
        logging.info("Dirigirse al siguiente link, generar y copiar el pin en el archivo 'code.txt':")
        logging.info(r.url)
        return url, OAUTH_TOKEN, OAUTH_TOKEN_SECRET

    """
    Esta función genera una espera hasta encontrar el código correcto en el archivo 'code.txt'
    Una vez cuen encuetra el código, lo retorna como resultado de la función.
    """
    def wait_for_pin_code(self):
        while True:
            if not os.path.exists("code.txt"):
                time.sleep(5)
                logging.debug("'code.txt' no existe, esperando el código en el archivo para empezar a escuchar Tweets"
                )
            else:
                pincode = 0
                with open("code.txt") as f:
                    pincode = int(f.read().strip())
                    logging.info("Código leído con éxito:" + str(pincode))
                return str(pincode)
            
    """
    Función que elimina el archivo 'code.txt'
    """
    def remove_old_code_file(self):
        if os.path.exists("code.txt"):
            os.remove("code.txt")
    
    """
    Función que genera la conexión a la API con autorización del código o pin
    """
    def auth_with_pin(self, APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, pincode):
        # genero la instancia de twitter usando Twithon
        twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
        final_step = twitter.get_authorized_tokens(pincode)
        logging.debug("Anterior OATH_TOKEN: " + str(OAUTH_TOKEN))
        logging.debug("Anterior OAUTH_TOKEN_SECRET: " + str(OAUTH_TOKEN_SECRET))
        OAUTH_TOKEN = final_step['oauth_token']
        OAUTH_TOKEN_SECRET = final_step['oauth_token_secret']
        logging.debug("Nuevo OATH_TOKEN: " + str(OAUTH_TOKEN))
        logging.debug("Nuevo OAUTH_TOKEN_SECRET: " + str(OAUTH_TOKEN_SECRET))
        return OAUTH_TOKEN, OAUTH_TOKEN_SECRET

# %%
# Clase que define una excepción 
class TooLongTermException(Exception):
    
    def __init__(self, index):
        self.index = index

    def get_too_long_index(self):
        return self.index

# %%
"""
Clase que permite buscar los tweets en tiempo real, para lo cual se herda de la clase TwithonStreamer
"""
class StreamListener(TwythonStreamer):
    
    # Genera una instancia de la clase
    def __init__(self, APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, comm_list):
        #inicializa la instancia invocando al constructor de la clase padre
        super().__init__(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
        #define un atributo propio llamado tweet_list
        self.tweet_list = comm_list

    # Redefino la función on_success en caso de que obtenga información y la agrega a la lista  
    def on_success(self, data):
        self.tweet_list.append(data)
        logging.info("tweet capturado")
    
    # Redefino la función on_error encaso
    # todo status_code distinto de 200 es un error
    def on_error(self, status_code, data):
        logging.error(status_code)
        logging.error(data)
        if int(status_code) == 406:
            data = str(data)
            try:
                index = int(data.strip().split()[4])
                logging.error("to remove index:" + str(index))
                raise TooLongTermException(index)
            except ValueError:
                logging.debug("ValueError while trying to extract number")

# %%
def get_authentication():
    
    # Defino una instancia de Authentication
    auth = Authentication()
    
    # Defino del formato del log para que muestre la fecha y hora del evento
    logging.basicConfig(
        format='%(levelname)s: %(asctime)s - %(message)s',
        datefmt='%m/%d/%Y %I:%M:%S %p',
        level=logging.INFO
    )

    logging.info("Borrando el archivo code.txt")
    auth.remove_old_code_file()

    logging.info("Obteniendo información del archivo config.json")
    APP_KEY, APP_SECRET, TERMS_FILE, STORAGE_PATH = auth.read_config_file("config.json")

    logging.info("Obteniendo las claves de autorización")
    url, OAUTH_TOKEN, OAUTH_TOKEN_SECRET = auth.get_oauth_link(APP_KEY, APP_SECRET)

    logging.info("Esperando el código en code.txt")
    pincode = auth.wait_for_pin_code()

    logging.info("Obteniendo autorización con el código")
    OAUTH_TOKEN, OAUTH_TOKEN_SECRET = auth.auth_with_pin(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, pincode)

    logging.info("Comienzo de lectura de tweets....")

    filter_terms = []
    with open(TERMS_FILE) as f:
        for term in f:
            filter_terms.append(term.strip())
    logging.info("Los términos a buscar en los tweets son " + str(filter_terms))

    return APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, filter_terms, STORAGE_PATH

# %%
# Defino una función para obtener los tweets
def twitter_listener(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, comm_list):
    
    # Instancio la clase StreamListener
    streamer = StreamListener(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, comm_list)
    
    while True:
        try:
            # Con la instancia generada filtro los tweets de acuerdo a los términos seteados
            streamer.statuses.filter(track=[', '.join(filter_terms)], language='es')
        except requests.exceptions.ChunkedEncodingError:
            print('Error. Continúa...\n')
            pass
        except IncompleteRead:
            print('Lectura incompleta. Continúa...')
            pass
        except TooLongTermException as e:
            index_to_remove = e.get_too_long_index()
            filter_terms.pop(index_to_remove)

# Defino una función para escribir los tweets encontrados
def twitter_writer(comm_list):
    internal_list = []
    time_start = time.time()
    while True:
        if len(internal_list) > 100:
            file_name = STORAGE_PATH + str(round(time.time())) + ".json"
            with open(file_name, 'w+', encoding='utf-8') as output_file:
                json.dump(internal_list, output_file, indent=4)
                internal_list = []
                logging.info('------- Data dumped -------')
                time_stop = time.time()
                logging.info('Tiempo transcurrido para obtener 100 tweets: {0:.2f}s'.format(time_stop - time_start))
                time_start = time.time()
        else:
            for i in range(len(comm_list)):
                internal_list.append(comm_list.pop())
            time.sleep(1)

# %%
if __name__ == '__main__':
    
    # Obtengo las autenticaciones y parámetros de la captura de tweets
    APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, filter_terms, STORAGE_PATH = get_authentication()
    comm_list =[]
    
    # Se genera un hilo pasando como target la función que leerá los tweets
    listener = Thread(target = twitter_listener, args = (APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET, comm_list ))
    listener.start()
    writer = Thread(target = twitter_writer, args = (comm_list,))
    writer.start()
    writer.join()
    listener.join()
# Out:
# INFO: 03/23/2019 06:34:59 PM - Borrando el archivo code.txt
# INFO: 03/23/2019 06:34:59 PM - Obteniendo información del archivo config.json
# INFO: 03/23/2019 06:34:59 PM - Obteniendo las claves de autorización
# INFO: 03/23/2019 06:35:01 PM - Dirigirse al siguiente link, generar y copiar el pin en el archivo 'code.txt':
# INFO: 03/23/2019 06:35:01 PM - https://api.twitter.com/oauth/authorize?oauth_token=_eD0kgAAAAAA9rRDAAABaax6b5c
# INFO: 03/23/2019 06:35:01 PM - Esperando el código en code.txt
# INFO: 03/23/2019 06:35:26 PM - Código leído con éxito:7680052
# INFO: 03/23/2019 06:35:26 PM - Obteniendo autorización con el código
# INFO: 03/23/2019 06:35:28 PM - Comienzo de lectura de tweets....
# INFO: 03/23/2019 06:35:28 PM - Los términos a buscar en los tweets son ['Kirchner', 'Macri', 'Lavagna']
# INFO: 03/23/2019 06:35:31 PM - tweet capturado
# INFO: 03/23/2019 06:35:32 PM - tweet capturado
# INFO: 03/23/2019 06:35:32 PM - tweet capturado
# INFO: 03/23/2019 06:35:33 PM - tweet capturado
# INFO: 03/23/2019 06:35:33 PM - tweet capturado
# INFO: 03/23/2019 06:35:33 PM - tweet capturado
# INFO: 03/23/2019 06:35:37 PM - tweet capturado
# INFO: 03/23/2019 06:35:38 PM - tweet capturado
# INFO: 03/23/2019 06:35:38 PM - tweet capturado
# INFO: 03/23/2019 06:35:39 PM - tweet capturado
# INFO: 03/23/2019 06:35:39 PM - tweet capturado
# INFO: 03/23/2019 06:35:40 PM - tweet capturado
# INFO: 03/23/2019 06:35:41 PM - tweet capturado
# INFO: 03/23/2019 06:35:42 PM - tweet capturado
# INFO: 03/23/2019 06:35:44 PM - tweet capturado
# INFO: 03/23/2019 06:35:44 PM - tweet capturado
# INFO: 03/23/2019 06:35:45 PM - tweet capturado
# INFO: 03/23/2019 06:35:46 PM - tweet capturado
# INFO: 03/23/2019 06:35:48 PM - tweet capturado
# INFO: 03/23/2019 06:35:48 PM - tweet capturado
# INFO: 03/23/2019 06:35:49 PM - tweet capturado
# INFO: 03/23/2019 06:35:49 PM - tweet capturado
# INFO: 03/23/2019 06:35:49 PM - tweet capturado
# INFO: 03/23/2019 06:35:51 PM - tweet capturado
# INFO: 03/23/2019 06:35:52 PM - tweet capturado
# INFO: 03/23/2019 06:35:52 PM - tweet capturado
# INFO: 03/23/2019 06:35:53 PM - tweet capturado
# INFO: 03/23/2019 06:35:55 PM - tweet capturado
# INFO: 03/23/2019 06:35:55 PM - tweet capturado
# INFO: 03/23/2019 06:35:56 PM - tweet capturado
# INFO: 03/23/2019 06:35:58 PM - tweet capturado
# INFO: 03/23/2019 06:35:58 PM - tweet capturado
# INFO: 03/23/2019 06:35:59 PM - tweet capturado
# INFO: 03/23/2019 06:35:59 PM - tweet capturado
# INFO: 03/23/2019 06:36:00 PM - tweet capturado
# INFO: 03/23/2019 06:36:00 PM - tweet capturado
# INFO: 03/23/2019 06:36:00 PM - tweet capturado
# INFO: 03/23/2019 06:36:01 PM - tweet capturado
# INFO: 03/23/2019 06:36:02 PM - tweet capturado
# INFO: 03/23/2019 06:36:04 PM - tweet capturado
# INFO: 03/23/2019 06:36:04 PM - tweet capturado
# INFO: 03/23/2019 06:36:06 PM - tweet capturado
# INFO: 03/23/2019 06:36:09 PM - tweet capturado
# INFO: 03/23/2019 06:36:09 PM - tweet capturado
# INFO: 03/23/2019 06:36:09 PM - tweet capturado
# INFO: 03/23/2019 06:36:09 PM - tweet capturado
# INFO: 03/23/2019 06:36:10 PM - tweet capturado
# INFO: 03/23/2019 06:36:10 PM - tweet capturado
# INFO: 03/23/2019 06:36:11 PM - tweet capturado
# INFO: 03/23/2019 06:36:12 PM - tweet capturado
# INFO: 03/23/2019 06:36:15 PM - tweet capturado
# INFO: 03/23/2019 06:36:18 PM - tweet capturado
# INFO: 03/23/2019 06:36:19 PM - tweet capturado
# INFO: 03/23/2019 06:36:19 PM - tweet capturado
# INFO: 03/23/2019 06:36:20 PM - tweet capturado
# INFO: 03/23/2019 06:36:20 PM - tweet capturado
# INFO: 03/23/2019 06:36:20 PM - tweet capturado
# INFO: 03/23/2019 06:36:20 PM - tweet capturado
# INFO: 03/23/2019 06:36:21 PM - tweet capturado
# INFO: 03/23/2019 06:36:21 PM - tweet capturado
# INFO: 03/23/2019 06:36:22 PM - tweet capturado
# INFO: 03/23/2019 06:36:22 PM - tweet capturado
# INFO: 03/23/2019 06:36:23 PM - tweet capturado
# INFO: 03/23/2019 06:36:23 PM - tweet capturado
# INFO: 03/23/2019 06:36:24 PM - tweet capturado
# INFO: 03/23/2019 06:36:24 PM - tweet capturado
# INFO: 03/23/2019 06:36:26 PM - tweet capturado
# INFO: 03/23/2019 06:36:26 PM - tweet capturado
# INFO: 03/23/2019 06:36:26 PM - tweet capturado
# INFO: 03/23/2019 06:36:26 PM - tweet capturado
# INFO: 03/23/2019 06:36:27 PM - tweet capturado
# INFO: 03/23/2019 06:36:28 PM - tweet capturado
# INFO: 03/23/2019 06:36:28 PM - tweet capturado
# INFO: 03/23/2019 06:36:29 PM - tweet capturado
# INFO: 03/23/2019 06:36:29 PM - tweet capturado
# INFO: 03/23/2019 06:36:30 PM - tweet capturado
# INFO: 03/23/2019 06:36:31 PM - tweet capturado
# INFO: 03/23/2019 06:36:32 PM - tweet capturado
# INFO: 03/23/2019 06:36:32 PM - tweet capturado
# INFO: 03/23/2019 06:36:32 PM - tweet capturado
# INFO: 03/23/2019 06:36:33 PM - tweet capturado
# INFO: 03/23/2019 06:36:34 PM - tweet capturado
# INFO: 03/23/2019 06:36:35 PM - tweet capturado
# INFO: 03/23/2019 06:36:36 PM - tweet capturado
# INFO: 03/23/2019 06:36:36 PM - tweet capturado
# INFO: 03/23/2019 06:36:38 PM - tweet capturado
# INFO: 03/23/2019 06:36:39 PM - tweet capturado
# INFO: 03/23/2019 06:36:40 PM - tweet capturado
# INFO: 03/23/2019 06:36:41 PM - tweet capturado
# INFO: 03/23/2019 06:36:41 PM - tweet capturado
# INFO: 03/23/2019 06:36:42 PM - tweet capturado
# INFO: 03/23/2019 06:36:42 PM - tweet capturado
# INFO: 03/23/2019 06:36:44 PM - tweet capturado
# INFO: 03/23/2019 06:36:44 PM - tweet capturado
# INFO: 03/23/2019 06:36:45 PM - tweet capturado
# INFO: 03/23/2019 06:36:45 PM - tweet capturado
# INFO: 03/23/2019 06:36:46 PM - tweet capturado
# INFO: 03/23/2019 06:36:46 PM - tweet capturado
# INFO: 03/23/2019 06:36:46 PM - tweet capturado
# INFO: 03/23/2019 06:36:46 PM - tweet capturado
# INFO: 03/23/2019 06:36:47 PM - tweet capturado
# INFO: 03/23/2019 06:36:47 PM - tweet capturado
# INFO: 03/23/2019 06:36:47 PM - tweet capturado
# INFO: 03/23/2019 06:36:48 PM - tweet capturado
# INFO: 03/23/2019 06:36:48 PM - tweet capturado
# INFO: 03/23/2019 06:36:49 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:36:49 PM - Tiempo transcurrido para obtener 100 tweets: 81.20s
# INFO: 03/23/2019 06:36:51 PM - tweet capturado
# INFO: 03/23/2019 06:36:51 PM - tweet capturado
# INFO: 03/23/2019 06:36:51 PM - tweet capturado
# INFO: 03/23/2019 06:36:51 PM - tweet capturado
# INFO: 03/23/2019 06:36:51 PM - tweet capturado
# INFO: 03/23/2019 06:36:52 PM - tweet capturado
# INFO: 03/23/2019 06:36:52 PM - tweet capturado
# INFO: 03/23/2019 06:36:52 PM - tweet capturado
# INFO: 03/23/2019 06:36:52 PM - tweet capturado
# INFO: 03/23/2019 06:36:53 PM - tweet capturado
# INFO: 03/23/2019 06:36:53 PM - tweet capturado
# INFO: 03/23/2019 06:36:54 PM - tweet capturado
# INFO: 03/23/2019 06:36:55 PM - tweet capturado
# INFO: 03/23/2019 06:36:56 PM - tweet capturado
# INFO: 03/23/2019 06:36:57 PM - tweet capturado
# INFO: 03/23/2019 06:36:58 PM - tweet capturado
# INFO: 03/23/2019 06:36:58 PM - tweet capturado
# INFO: 03/23/2019 06:37:00 PM - tweet capturado
# INFO: 03/23/2019 06:37:03 PM - tweet capturado
# INFO: 03/23/2019 06:37:04 PM - tweet capturado
# INFO: 03/23/2019 06:37:06 PM - tweet capturado
# INFO: 03/23/2019 06:37:06 PM - tweet capturado
# INFO: 03/23/2019 06:37:06 PM - tweet capturado
# INFO: 03/23/2019 06:37:08 PM - tweet capturado
# INFO: 03/23/2019 06:37:08 PM - tweet capturado
# INFO: 03/23/2019 06:37:09 PM - tweet capturado
# INFO: 03/23/2019 06:37:10 PM - tweet capturado
# INFO: 03/23/2019 06:37:10 PM - tweet capturado
# INFO: 03/23/2019 06:37:12 PM - tweet capturado
# INFO: 03/23/2019 06:37:16 PM - tweet capturado
# INFO: 03/23/2019 06:37:16 PM - tweet capturado
# INFO: 03/23/2019 06:37:17 PM - tweet capturado
# INFO: 03/23/2019 06:37:18 PM - tweet capturado
# INFO: 03/23/2019 06:37:20 PM - tweet capturado
# INFO: 03/23/2019 06:37:20 PM - tweet capturado
# INFO: 03/23/2019 06:37:20 PM - tweet capturado
# INFO: 03/23/2019 06:37:21 PM - tweet capturado
# INFO: 03/23/2019 06:37:21 PM - tweet capturado
# INFO: 03/23/2019 06:37:23 PM - tweet capturado
# INFO: 03/23/2019 06:37:23 PM - tweet capturado
# INFO: 03/23/2019 06:37:25 PM - tweet capturado
# INFO: 03/23/2019 06:37:27 PM - tweet capturado
# INFO: 03/23/2019 06:37:27 PM - tweet capturado
# INFO: 03/23/2019 06:37:28 PM - tweet capturado
# INFO: 03/23/2019 06:37:28 PM - tweet capturado
# INFO: 03/23/2019 06:37:28 PM - tweet capturado
# INFO: 03/23/2019 06:37:29 PM - tweet capturado
# INFO: 03/23/2019 06:37:29 PM - tweet capturado
# INFO: 03/23/2019 06:37:32 PM - tweet capturado
# INFO: 03/23/2019 06:37:32 PM - tweet capturado
# INFO: 03/23/2019 06:37:32 PM - tweet capturado
# INFO: 03/23/2019 06:37:33 PM - tweet capturado
# INFO: 03/23/2019 06:37:37 PM - tweet capturado
# INFO: 03/23/2019 06:37:37 PM - tweet capturado
# INFO: 03/23/2019 06:37:38 PM - tweet capturado
# INFO: 03/23/2019 06:37:38 PM - tweet capturado
# INFO: 03/23/2019 06:37:39 PM - tweet capturado
# INFO: 03/23/2019 06:37:40 PM - tweet capturado
# INFO: 03/23/2019 06:37:42 PM - tweet capturado
# INFO: 03/23/2019 06:37:43 PM - tweet capturado
# INFO: 03/23/2019 06:37:44 PM - tweet capturado
# INFO: 03/23/2019 06:37:45 PM - tweet capturado
# INFO: 03/23/2019 06:37:46 PM - tweet capturado
# INFO: 03/23/2019 06:37:46 PM - tweet capturado
# INFO: 03/23/2019 06:37:46 PM - tweet capturado
# INFO: 03/23/2019 06:37:46 PM - tweet capturado
# INFO: 03/23/2019 06:37:47 PM - tweet capturado
# INFO: 03/23/2019 06:37:48 PM - tweet capturado
# INFO: 03/23/2019 06:37:48 PM - tweet capturado
# INFO: 03/23/2019 06:37:48 PM - tweet capturado
# INFO: 03/23/2019 06:37:48 PM - tweet capturado
# INFO: 03/23/2019 06:37:49 PM - tweet capturado
# INFO: 03/23/2019 06:37:50 PM - tweet capturado
# INFO: 03/23/2019 06:37:51 PM - tweet capturado
# INFO: 03/23/2019 06:37:52 PM - tweet capturado
# INFO: 03/23/2019 06:37:52 PM - tweet capturado
# INFO: 03/23/2019 06:37:54 PM - tweet capturado
# INFO: 03/23/2019 06:37:55 PM - tweet capturado
# INFO: 03/23/2019 06:37:55 PM - tweet capturado
# INFO: 03/23/2019 06:37:56 PM - tweet capturado
# INFO: 03/23/2019 06:37:56 PM - tweet capturado
# INFO: 03/23/2019 06:37:57 PM - tweet capturado
# INFO: 03/23/2019 06:37:57 PM - tweet capturado
# INFO: 03/23/2019 06:37:57 PM - tweet capturado
# INFO: 03/23/2019 06:37:58 PM - tweet capturado
# INFO: 03/23/2019 06:38:00 PM - tweet capturado
# INFO: 03/23/2019 06:38:00 PM - tweet capturado
# INFO: 03/23/2019 06:38:00 PM - tweet capturado
# INFO: 03/23/2019 06:38:00 PM - tweet capturado
# INFO: 03/23/2019 06:38:00 PM - tweet capturado
# INFO: 03/23/2019 06:38:03 PM - tweet capturado
# INFO: 03/23/2019 06:38:03 PM - tweet capturado
# INFO: 03/23/2019 06:38:04 PM - tweet capturado
# INFO: 03/23/2019 06:38:05 PM - tweet capturado
# INFO: 03/23/2019 06:38:05 PM - tweet capturado
# INFO: 03/23/2019 06:38:06 PM - tweet capturado
# INFO: 03/23/2019 06:38:06 PM - tweet capturado
# INFO: 03/23/2019 06:38:07 PM - tweet capturado
# INFO: 03/23/2019 06:38:07 PM - tweet capturado
# INFO: 03/23/2019 06:38:09 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:38:09 PM - Tiempo transcurrido para obtener 100 tweets: 80.34s
# INFO: 03/23/2019 06:38:09 PM - tweet capturado
# INFO: 03/23/2019 06:38:10 PM - tweet capturado
# INFO: 03/23/2019 06:38:10 PM - tweet capturado
# INFO: 03/23/2019 06:38:11 PM - tweet capturado
# INFO: 03/23/2019 06:38:11 PM - tweet capturado
# INFO: 03/23/2019 06:38:11 PM - tweet capturado
# INFO: 03/23/2019 06:38:13 PM - tweet capturado
# INFO: 03/23/2019 06:38:14 PM - tweet capturado
# INFO: 03/23/2019 06:38:14 PM - tweet capturado
# INFO: 03/23/2019 06:38:15 PM - tweet capturado
# INFO: 03/23/2019 06:38:15 PM - tweet capturado
# INFO: 03/23/2019 06:38:16 PM - tweet capturado
# INFO: 03/23/2019 06:38:16 PM - tweet capturado
# INFO: 03/23/2019 06:38:17 PM - tweet capturado
# INFO: 03/23/2019 06:38:18 PM - tweet capturado
# INFO: 03/23/2019 06:38:19 PM - tweet capturado
# INFO: 03/23/2019 06:38:20 PM - tweet capturado
# INFO: 03/23/2019 06:38:20 PM - tweet capturado
# INFO: 03/23/2019 06:38:20 PM - tweet capturado
# INFO: 03/23/2019 06:38:21 PM - tweet capturado
# INFO: 03/23/2019 06:38:22 PM - tweet capturado
# INFO: 03/23/2019 06:38:22 PM - tweet capturado
# INFO: 03/23/2019 06:38:23 PM - tweet capturado
# INFO: 03/23/2019 06:38:23 PM - tweet capturado
# INFO: 03/23/2019 06:38:23 PM - tweet capturado
# INFO: 03/23/2019 06:38:25 PM - tweet capturado
# INFO: 03/23/2019 06:38:25 PM - tweet capturado
# INFO: 03/23/2019 06:38:25 PM - tweet capturado
# INFO: 03/23/2019 06:38:26 PM - tweet capturado
# INFO: 03/23/2019 06:38:26 PM - tweet capturado
# INFO: 03/23/2019 06:38:27 PM - tweet capturado
# INFO: 03/23/2019 06:38:28 PM - tweet capturado
# INFO: 03/23/2019 06:38:28 PM - tweet capturado
# INFO: 03/23/2019 06:38:29 PM - tweet capturado
# INFO: 03/23/2019 06:38:30 PM - tweet capturado
# INFO: 03/23/2019 06:38:31 PM - tweet capturado
# INFO: 03/23/2019 06:38:31 PM - tweet capturado
# INFO: 03/23/2019 06:38:31 PM - tweet capturado
# INFO: 03/23/2019 06:38:32 PM - tweet capturado
# INFO: 03/23/2019 06:38:32 PM - tweet capturado
# INFO: 03/23/2019 06:38:32 PM - tweet capturado
# INFO: 03/23/2019 06:38:35 PM - tweet capturado
# INFO: 03/23/2019 06:38:36 PM - tweet capturado
# INFO: 03/23/2019 06:38:37 PM - tweet capturado
# INFO: 03/23/2019 06:38:41 PM - tweet capturado
# INFO: 03/23/2019 06:38:43 PM - tweet capturado
# INFO: 03/23/2019 06:38:43 PM - tweet capturado
# INFO: 03/23/2019 06:38:44 PM - tweet capturado
# INFO: 03/23/2019 06:38:44 PM - tweet capturado
# INFO: 03/23/2019 06:38:45 PM - tweet capturado
# INFO: 03/23/2019 06:38:45 PM - tweet capturado
# INFO: 03/23/2019 06:38:47 PM - tweet capturado
# INFO: 03/23/2019 06:38:49 PM - tweet capturado
# INFO: 03/23/2019 06:38:50 PM - tweet capturado
# INFO: 03/23/2019 06:38:50 PM - tweet capturado
# INFO: 03/23/2019 06:38:51 PM - tweet capturado
# INFO: 03/23/2019 06:38:54 PM - tweet capturado
# INFO: 03/23/2019 06:38:55 PM - tweet capturado
# INFO: 03/23/2019 06:38:55 PM - tweet capturado
# INFO: 03/23/2019 06:38:56 PM - tweet capturado
# INFO: 03/23/2019 06:38:57 PM - tweet capturado
# INFO: 03/23/2019 06:38:58 PM - tweet capturado
# INFO: 03/23/2019 06:38:58 PM - tweet capturado
# INFO: 03/23/2019 06:38:58 PM - tweet capturado
# INFO: 03/23/2019 06:38:59 PM - tweet capturado
# INFO: 03/23/2019 06:38:59 PM - tweet capturado
# INFO: 03/23/2019 06:39:00 PM - tweet capturado
# INFO: 03/23/2019 06:39:00 PM - tweet capturado
# INFO: 03/23/2019 06:39:00 PM - tweet capturado
# INFO: 03/23/2019 06:39:01 PM - tweet capturado
# INFO: 03/23/2019 06:39:01 PM - tweet capturado
# INFO: 03/23/2019 06:39:02 PM - tweet capturado
# INFO: 03/23/2019 06:39:03 PM - tweet capturado
# INFO: 03/23/2019 06:39:03 PM - tweet capturado
# INFO: 03/23/2019 06:39:04 PM - tweet capturado
# INFO: 03/23/2019 06:39:04 PM - tweet capturado
# INFO: 03/23/2019 06:39:04 PM - tweet capturado
# INFO: 03/23/2019 06:39:05 PM - tweet capturado
# INFO: 03/23/2019 06:39:07 PM - tweet capturado
# INFO: 03/23/2019 06:39:08 PM - tweet capturado
# INFO: 03/23/2019 06:39:08 PM - tweet capturado
# INFO: 03/23/2019 06:39:10 PM - tweet capturado
# INFO: 03/23/2019 06:39:10 PM - tweet capturado
# INFO: 03/23/2019 06:39:10 PM - tweet capturado
# INFO: 03/23/2019 06:39:11 PM - tweet capturado
# INFO: 03/23/2019 06:39:12 PM - tweet capturado
# INFO: 03/23/2019 06:39:15 PM - tweet capturado
# INFO: 03/23/2019 06:39:16 PM - tweet capturado
# INFO: 03/23/2019 06:39:16 PM - tweet capturado
# INFO: 03/23/2019 06:39:16 PM - tweet capturado
# INFO: 03/23/2019 06:39:16 PM - tweet capturado
# INFO: 03/23/2019 06:39:17 PM - tweet capturado
# INFO: 03/23/2019 06:39:19 PM - tweet capturado
# INFO: 03/23/2019 06:39:20 PM - tweet capturado
# INFO: 03/23/2019 06:39:20 PM - tweet capturado
# INFO: 03/23/2019 06:39:20 PM - tweet capturado
# INFO: 03/23/2019 06:39:21 PM - tweet capturado
# INFO: 03/23/2019 06:39:22 PM - tweet capturado
# INFO: 03/23/2019 06:39:22 PM - tweet capturado
# INFO: 03/23/2019 06:39:23 PM - tweet capturado
# INFO: 03/23/2019 06:39:23 PM - tweet capturado
# INFO: 03/23/2019 06:39:24 PM - tweet capturado
# INFO: 03/23/2019 06:39:26 PM - tweet capturado
# INFO: 03/23/2019 06:39:26 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:39:26 PM - Tiempo transcurrido para obtener 100 tweets: 76.69s
# INFO: 03/23/2019 06:39:27 PM - tweet capturado
# INFO: 03/23/2019 06:39:27 PM - tweet capturado
# INFO: 03/23/2019 06:39:27 PM - tweet capturado
# INFO: 03/23/2019 06:39:28 PM - tweet capturado
# INFO: 03/23/2019 06:39:28 PM - tweet capturado
# INFO: 03/23/2019 06:39:29 PM - tweet capturado
# INFO: 03/23/2019 06:39:29 PM - tweet capturado
# INFO: 03/23/2019 06:39:29 PM - tweet capturado
# INFO: 03/23/2019 06:39:30 PM - tweet capturado
# INFO: 03/23/2019 06:39:31 PM - tweet capturado
# INFO: 03/23/2019 06:39:34 PM - tweet capturado
# INFO: 03/23/2019 06:39:35 PM - tweet capturado
# INFO: 03/23/2019 06:39:35 PM - tweet capturado
# INFO: 03/23/2019 06:39:38 PM - tweet capturado
# INFO: 03/23/2019 06:39:38 PM - tweet capturado
# INFO: 03/23/2019 06:39:38 PM - tweet capturado
# INFO: 03/23/2019 06:39:41 PM - tweet capturado
# INFO: 03/23/2019 06:39:42 PM - tweet capturado
# INFO: 03/23/2019 06:39:42 PM - tweet capturado
# INFO: 03/23/2019 06:39:44 PM - tweet capturado
# INFO: 03/23/2019 06:39:44 PM - tweet capturado
# INFO: 03/23/2019 06:39:45 PM - tweet capturado
# INFO: 03/23/2019 06:39:45 PM - tweet capturado
# INFO: 03/23/2019 06:39:47 PM - tweet capturado
# INFO: 03/23/2019 06:39:49 PM - tweet capturado
# INFO: 03/23/2019 06:39:50 PM - tweet capturado
# INFO: 03/23/2019 06:39:50 PM - tweet capturado
# INFO: 03/23/2019 06:39:50 PM - tweet capturado
# INFO: 03/23/2019 06:39:51 PM - tweet capturado
# INFO: 03/23/2019 06:39:52 PM - tweet capturado
# INFO: 03/23/2019 06:39:53 PM - tweet capturado
# INFO: 03/23/2019 06:39:53 PM - tweet capturado
# INFO: 03/23/2019 06:39:54 PM - tweet capturado
# INFO: 03/23/2019 06:39:55 PM - tweet capturado
# INFO: 03/23/2019 06:39:55 PM - tweet capturado
# INFO: 03/23/2019 06:39:56 PM - tweet capturado
# INFO: 03/23/2019 06:39:56 PM - tweet capturado
# INFO: 03/23/2019 06:39:56 PM - tweet capturado
# INFO: 03/23/2019 06:39:56 PM - tweet capturado
# INFO: 03/23/2019 06:39:56 PM - tweet capturado
# INFO: 03/23/2019 06:39:56 PM - tweet capturado
# INFO: 03/23/2019 06:39:57 PM - tweet capturado
# INFO: 03/23/2019 06:39:58 PM - tweet capturado
# INFO: 03/23/2019 06:39:59 PM - tweet capturado
# INFO: 03/23/2019 06:39:59 PM - tweet capturado
# INFO: 03/23/2019 06:40:00 PM - tweet capturado
# INFO: 03/23/2019 06:40:00 PM - tweet capturado
# INFO: 03/23/2019 06:40:01 PM - tweet capturado
# INFO: 03/23/2019 06:40:01 PM - tweet capturado
# INFO: 03/23/2019 06:40:02 PM - tweet capturado
# INFO: 03/23/2019 06:40:03 PM - tweet capturado
# INFO: 03/23/2019 06:40:03 PM - tweet capturado
# INFO: 03/23/2019 06:40:04 PM - tweet capturado
# INFO: 03/23/2019 06:40:05 PM - tweet capturado
# INFO: 03/23/2019 06:40:06 PM - tweet capturado
# INFO: 03/23/2019 06:40:06 PM - tweet capturado
# INFO: 03/23/2019 06:40:07 PM - tweet capturado
# INFO: 03/23/2019 06:40:08 PM - tweet capturado
# INFO: 03/23/2019 06:40:09 PM - tweet capturado
# INFO: 03/23/2019 06:40:09 PM - tweet capturado
# INFO: 03/23/2019 06:40:10 PM - tweet capturado
# INFO: 03/23/2019 06:40:10 PM - tweet capturado
# INFO: 03/23/2019 06:40:10 PM - tweet capturado
# INFO: 03/23/2019 06:40:12 PM - tweet capturado
# INFO: 03/23/2019 06:40:12 PM - tweet capturado
# INFO: 03/23/2019 06:40:13 PM - tweet capturado
# INFO: 03/23/2019 06:40:14 PM - tweet capturado
# INFO: 03/23/2019 06:40:14 PM - tweet capturado
# INFO: 03/23/2019 06:40:14 PM - tweet capturado
# INFO: 03/23/2019 06:40:14 PM - tweet capturado
# INFO: 03/23/2019 06:40:16 PM - tweet capturado
# INFO: 03/23/2019 06:40:16 PM - tweet capturado
# INFO: 03/23/2019 06:40:16 PM - tweet capturado
# INFO: 03/23/2019 06:40:17 PM - tweet capturado
# INFO: 03/23/2019 06:40:19 PM - tweet capturado
# INFO: 03/23/2019 06:40:19 PM - tweet capturado
# INFO: 03/23/2019 06:40:19 PM - tweet capturado
# INFO: 03/23/2019 06:40:19 PM - tweet capturado
# INFO: 03/23/2019 06:40:21 PM - tweet capturado
# INFO: 03/23/2019 06:40:21 PM - tweet capturado
# INFO: 03/23/2019 06:40:22 PM - tweet capturado
# INFO: 03/23/2019 06:40:22 PM - tweet capturado
# INFO: 03/23/2019 06:40:22 PM - tweet capturado
# INFO: 03/23/2019 06:40:22 PM - tweet capturado
# INFO: 03/23/2019 06:40:23 PM - tweet capturado
# INFO: 03/23/2019 06:40:23 PM - tweet capturado
# INFO: 03/23/2019 06:40:23 PM - tweet capturado
# INFO: 03/23/2019 06:40:23 PM - tweet capturado
# INFO: 03/23/2019 06:40:24 PM - tweet capturado
# INFO: 03/23/2019 06:40:24 PM - tweet capturado
# INFO: 03/23/2019 06:40:24 PM - tweet capturado
# INFO: 03/23/2019 06:40:25 PM - tweet capturado
# INFO: 03/23/2019 06:40:26 PM - tweet capturado
# INFO: 03/23/2019 06:40:26 PM - tweet capturado
# INFO: 03/23/2019 06:40:26 PM - tweet capturado
# INFO: 03/23/2019 06:40:27 PM - tweet capturado
# INFO: 03/23/2019 06:40:28 PM - tweet capturado
# INFO: 03/23/2019 06:40:28 PM - tweet capturado
# INFO: 03/23/2019 06:40:28 PM - tweet capturado
# INFO: 03/23/2019 06:40:29 PM - tweet capturado
# INFO: 03/23/2019 06:40:29 PM - tweet capturado
# INFO: 03/23/2019 06:40:30 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:40:30 PM - Tiempo transcurrido para obtener 100 tweets: 64.23s
# INFO: 03/23/2019 06:40:30 PM - tweet capturado
# INFO: 03/23/2019 06:40:31 PM - tweet capturado
# INFO: 03/23/2019 06:40:31 PM - tweet capturado
# INFO: 03/23/2019 06:40:31 PM - tweet capturado
# INFO: 03/23/2019 06:40:32 PM - tweet capturado
# INFO: 03/23/2019 06:40:33 PM - tweet capturado
# INFO: 03/23/2019 06:40:35 PM - tweet capturado
# INFO: 03/23/2019 06:40:35 PM - tweet capturado
# INFO: 03/23/2019 06:40:36 PM - tweet capturado
# INFO: 03/23/2019 06:40:37 PM - tweet capturado
# INFO: 03/23/2019 06:40:38 PM - tweet capturado
# INFO: 03/23/2019 06:40:39 PM - tweet capturado
# INFO: 03/23/2019 06:40:40 PM - tweet capturado
# INFO: 03/23/2019 06:40:40 PM - tweet capturado
# INFO: 03/23/2019 06:40:42 PM - tweet capturado
# INFO: 03/23/2019 06:40:43 PM - tweet capturado
# INFO: 03/23/2019 06:40:45 PM - tweet capturado
# INFO: 03/23/2019 06:40:47 PM - tweet capturado
# INFO: 03/23/2019 06:40:49 PM - tweet capturado
# INFO: 03/23/2019 06:40:50 PM - tweet capturado
# INFO: 03/23/2019 06:40:50 PM - tweet capturado
# INFO: 03/23/2019 06:40:51 PM - tweet capturado
# INFO: 03/23/2019 06:40:51 PM - tweet capturado
# INFO: 03/23/2019 06:40:52 PM - tweet capturado
# INFO: 03/23/2019 06:40:52 PM - tweet capturado
# INFO: 03/23/2019 06:40:53 PM - tweet capturado
# INFO: 03/23/2019 06:40:54 PM - tweet capturado
# INFO: 03/23/2019 06:40:54 PM - tweet capturado
# INFO: 03/23/2019 06:40:55 PM - tweet capturado
# INFO: 03/23/2019 06:40:55 PM - tweet capturado
# INFO: 03/23/2019 06:40:56 PM - tweet capturado
# INFO: 03/23/2019 06:40:56 PM - tweet capturado
# INFO: 03/23/2019 06:40:56 PM - tweet capturado
# INFO: 03/23/2019 06:40:57 PM - tweet capturado
# INFO: 03/23/2019 06:40:58 PM - tweet capturado
# INFO: 03/23/2019 06:40:58 PM - tweet capturado
# INFO: 03/23/2019 06:40:58 PM - tweet capturado
# INFO: 03/23/2019 06:40:59 PM - tweet capturado
# INFO: 03/23/2019 06:41:00 PM - tweet capturado
# INFO: 03/23/2019 06:41:00 PM - tweet capturado
# INFO: 03/23/2019 06:41:01 PM - tweet capturado
# INFO: 03/23/2019 06:41:02 PM - tweet capturado
# INFO: 03/23/2019 06:41:02 PM - tweet capturado
# INFO: 03/23/2019 06:41:03 PM - tweet capturado
# INFO: 03/23/2019 06:41:03 PM - tweet capturado
# INFO: 03/23/2019 06:41:04 PM - tweet capturado
# INFO: 03/23/2019 06:41:05 PM - tweet capturado
# INFO: 03/23/2019 06:41:06 PM - tweet capturado
# INFO: 03/23/2019 06:41:06 PM - tweet capturado
# INFO: 03/23/2019 06:41:06 PM - tweet capturado
# INFO: 03/23/2019 06:41:07 PM - tweet capturado
# INFO: 03/23/2019 06:41:08 PM - tweet capturado
# INFO: 03/23/2019 06:41:09 PM - tweet capturado
# INFO: 03/23/2019 06:41:09 PM - tweet capturado
# INFO: 03/23/2019 06:41:10 PM - tweet capturado
# INFO: 03/23/2019 06:41:12 PM - tweet capturado
# INFO: 03/23/2019 06:41:13 PM - tweet capturado
# INFO: 03/23/2019 06:41:13 PM - tweet capturado
# INFO: 03/23/2019 06:41:15 PM - tweet capturado
# INFO: 03/23/2019 06:41:15 PM - tweet capturado
# INFO: 03/23/2019 06:41:15 PM - tweet capturado
# INFO: 03/23/2019 06:41:16 PM - tweet capturado
# INFO: 03/23/2019 06:41:18 PM - tweet capturado
# INFO: 03/23/2019 06:41:18 PM - tweet capturado
# INFO: 03/23/2019 06:41:18 PM - tweet capturado
# INFO: 03/23/2019 06:41:18 PM - tweet capturado
# INFO: 03/23/2019 06:41:18 PM - tweet capturado
# INFO: 03/23/2019 06:41:18 PM - tweet capturado
# INFO: 03/23/2019 06:41:21 PM - tweet capturado
# INFO: 03/23/2019 06:41:22 PM - tweet capturado
# INFO: 03/23/2019 06:41:22 PM - tweet capturado
# INFO: 03/23/2019 06:41:23 PM - tweet capturado
# INFO: 03/23/2019 06:41:23 PM - tweet capturado
# INFO: 03/23/2019 06:41:23 PM - tweet capturado
# INFO: 03/23/2019 06:41:24 PM - tweet capturado
# INFO: 03/23/2019 06:41:24 PM - tweet capturado
# INFO: 03/23/2019 06:41:25 PM - tweet capturado
# INFO: 03/23/2019 06:41:26 PM - tweet capturado
# INFO: 03/23/2019 06:41:28 PM - tweet capturado
# INFO: 03/23/2019 06:41:28 PM - tweet capturado
# INFO: 03/23/2019 06:41:29 PM - tweet capturado
# INFO: 03/23/2019 06:41:29 PM - tweet capturado
# INFO: 03/23/2019 06:41:30 PM - tweet capturado
# INFO: 03/23/2019 06:41:30 PM - tweet capturado
# INFO: 03/23/2019 06:41:30 PM - tweet capturado
# INFO: 03/23/2019 06:41:30 PM - tweet capturado
# INFO: 03/23/2019 06:41:31 PM - tweet capturado
# INFO: 03/23/2019 06:41:31 PM - tweet capturado
# INFO: 03/23/2019 06:41:31 PM - tweet capturado
# INFO: 03/23/2019 06:41:33 PM - tweet capturado
# INFO: 03/23/2019 06:41:33 PM - tweet capturado
# INFO: 03/23/2019 06:41:33 PM - tweet capturado
# INFO: 03/23/2019 06:41:34 PM - tweet capturado
# INFO: 03/23/2019 06:41:34 PM - tweet capturado
# INFO: 03/23/2019 06:41:34 PM - tweet capturado
# INFO: 03/23/2019 06:41:34 PM - tweet capturado
# INFO: 03/23/2019 06:41:34 PM - tweet capturado
# INFO: 03/23/2019 06:41:35 PM - tweet capturado
# INFO: 03/23/2019 06:41:35 PM - tweet capturado
# INFO: 03/23/2019 06:41:36 PM - tweet capturado
# INFO: 03/23/2019 06:41:36 PM - tweet capturado
# INFO: 03/23/2019 06:41:37 PM - tweet capturado
# INFO: 03/23/2019 06:41:37 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:41:37 PM - Tiempo transcurrido para obtener 100 tweets: 67.26s
# INFO: 03/23/2019 06:41:37 PM - tweet capturado
# INFO: 03/23/2019 06:41:38 PM - tweet capturado
# INFO: 03/23/2019 06:41:39 PM - tweet capturado
# INFO: 03/23/2019 06:41:40 PM - tweet capturado
# INFO: 03/23/2019 06:41:41 PM - tweet capturado
# INFO: 03/23/2019 06:41:44 PM - tweet capturado
# INFO: 03/23/2019 06:41:45 PM - tweet capturado
# INFO: 03/23/2019 06:41:46 PM - tweet capturado
# INFO: 03/23/2019 06:41:46 PM - tweet capturado
# INFO: 03/23/2019 06:41:47 PM - tweet capturado
# INFO: 03/23/2019 06:41:48 PM - tweet capturado
# INFO: 03/23/2019 06:41:49 PM - tweet capturado
# INFO: 03/23/2019 06:41:49 PM - tweet capturado
# INFO: 03/23/2019 06:41:53 PM - tweet capturado
# INFO: 03/23/2019 06:41:54 PM - tweet capturado
# INFO: 03/23/2019 06:41:55 PM - tweet capturado
# INFO: 03/23/2019 06:41:55 PM - tweet capturado
# INFO: 03/23/2019 06:41:55 PM - tweet capturado
# INFO: 03/23/2019 06:41:57 PM - tweet capturado
# INFO: 03/23/2019 06:41:57 PM - tweet capturado
# INFO: 03/23/2019 06:41:57 PM - tweet capturado
# INFO: 03/23/2019 06:41:58 PM - tweet capturado
# INFO: 03/23/2019 06:41:59 PM - tweet capturado
# INFO: 03/23/2019 06:41:59 PM - tweet capturado
# INFO: 03/23/2019 06:42:00 PM - tweet capturado
# INFO: 03/23/2019 06:42:01 PM - tweet capturado
# INFO: 03/23/2019 06:42:01 PM - tweet capturado
# INFO: 03/23/2019 06:42:01 PM - tweet capturado
# INFO: 03/23/2019 06:42:01 PM - tweet capturado
# INFO: 03/23/2019 06:42:01 PM - tweet capturado
# INFO: 03/23/2019 06:42:02 PM - tweet capturado
# INFO: 03/23/2019 06:42:02 PM - tweet capturado
# INFO: 03/23/2019 06:42:02 PM - tweet capturado
# INFO: 03/23/2019 06:42:03 PM - tweet capturado
# INFO: 03/23/2019 06:42:04 PM - tweet capturado
# INFO: 03/23/2019 06:42:05 PM - tweet capturado
# INFO: 03/23/2019 06:42:07 PM - tweet capturado
# INFO: 03/23/2019 06:42:07 PM - tweet capturado
# INFO: 03/23/2019 06:42:07 PM - tweet capturado
# INFO: 03/23/2019 06:42:08 PM - tweet capturado
# INFO: 03/23/2019 06:42:09 PM - tweet capturado
# INFO: 03/23/2019 06:42:09 PM - tweet capturado
# INFO: 03/23/2019 06:42:10 PM - tweet capturado
# INFO: 03/23/2019 06:42:11 PM - tweet capturado
# INFO: 03/23/2019 06:42:12 PM - tweet capturado
# INFO: 03/23/2019 06:42:13 PM - tweet capturado
# INFO: 03/23/2019 06:42:13 PM - tweet capturado
# INFO: 03/23/2019 06:42:14 PM - tweet capturado
# INFO: 03/23/2019 06:42:14 PM - tweet capturado
# INFO: 03/23/2019 06:42:16 PM - tweet capturado
# INFO: 03/23/2019 06:42:16 PM - tweet capturado
# INFO: 03/23/2019 06:42:17 PM - tweet capturado
# INFO: 03/23/2019 06:42:18 PM - tweet capturado
# INFO: 03/23/2019 06:42:18 PM - tweet capturado
# INFO: 03/23/2019 06:42:18 PM - tweet capturado
# INFO: 03/23/2019 06:42:18 PM - tweet capturado
# INFO: 03/23/2019 06:42:18 PM - tweet capturado
# INFO: 03/23/2019 06:42:20 PM - tweet capturado
# INFO: 03/23/2019 06:42:20 PM - tweet capturado
# INFO: 03/23/2019 06:42:20 PM - tweet capturado
# INFO: 03/23/2019 06:42:21 PM - tweet capturado
# INFO: 03/23/2019 06:42:22 PM - tweet capturado
# INFO: 03/23/2019 06:42:23 PM - tweet capturado
# INFO: 03/23/2019 06:42:23 PM - tweet capturado
# INFO: 03/23/2019 06:42:23 PM - tweet capturado
# INFO: 03/23/2019 06:42:24 PM - tweet capturado
# INFO: 03/23/2019 06:42:24 PM - tweet capturado
# INFO: 03/23/2019 06:42:25 PM - tweet capturado
# INFO: 03/23/2019 06:42:25 PM - tweet capturado
# INFO: 03/23/2019 06:42:25 PM - tweet capturado
# INFO: 03/23/2019 06:42:26 PM - tweet capturado
# INFO: 03/23/2019 06:42:26 PM - tweet capturado
# INFO: 03/23/2019 06:42:28 PM - tweet capturado
# INFO: 03/23/2019 06:42:28 PM - tweet capturado
# INFO: 03/23/2019 06:42:29 PM - tweet capturado
# INFO: 03/23/2019 06:42:29 PM - tweet capturado
# INFO: 03/23/2019 06:42:31 PM - tweet capturado
# INFO: 03/23/2019 06:42:31 PM - tweet capturado
# INFO: 03/23/2019 06:42:32 PM - tweet capturado
# INFO: 03/23/2019 06:42:33 PM - tweet capturado
# INFO: 03/23/2019 06:42:33 PM - tweet capturado
# INFO: 03/23/2019 06:42:33 PM - tweet capturado
# INFO: 03/23/2019 06:42:33 PM - tweet capturado
# INFO: 03/23/2019 06:42:33 PM - tweet capturado
# INFO: 03/23/2019 06:42:33 PM - tweet capturado
# INFO: 03/23/2019 06:42:35 PM - tweet capturado
# INFO: 03/23/2019 06:42:35 PM - tweet capturado
# INFO: 03/23/2019 06:42:36 PM - tweet capturado
# INFO: 03/23/2019 06:42:36 PM - tweet capturado
# INFO: 03/23/2019 06:42:36 PM - tweet capturado
# INFO: 03/23/2019 06:42:36 PM - tweet capturado
# INFO: 03/23/2019 06:42:38 PM - tweet capturado
# INFO: 03/23/2019 06:42:40 PM - tweet capturado
# INFO: 03/23/2019 06:42:40 PM - tweet capturado
# INFO: 03/23/2019 06:42:40 PM - tweet capturado
# INFO: 03/23/2019 06:42:40 PM - tweet capturado
# INFO: 03/23/2019 06:42:40 PM - tweet capturado
# INFO: 03/23/2019 06:42:40 PM - tweet capturado
# INFO: 03/23/2019 06:42:41 PM - tweet capturado
# INFO: 03/23/2019 06:42:41 PM - tweet capturado
# INFO: 03/23/2019 06:42:41 PM - tweet capturado
# INFO: 03/23/2019 06:42:41 PM - tweet capturado
# INFO: 03/23/2019 06:42:41 PM - tweet capturado
# INFO: 03/23/2019 06:42:41 PM - tweet capturado
# INFO: 03/23/2019 06:42:42 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:42:42 PM - Tiempo transcurrido para obtener 100 tweets: 65.17s
# INFO: 03/23/2019 06:42:43 PM - tweet capturado
# INFO: 03/23/2019 06:42:44 PM - tweet capturado
# INFO: 03/23/2019 06:42:44 PM - tweet capturado
# INFO: 03/23/2019 06:42:45 PM - tweet capturado
# INFO: 03/23/2019 06:42:45 PM - tweet capturado
# INFO: 03/23/2019 06:42:45 PM - tweet capturado
# INFO: 03/23/2019 06:42:50 PM - tweet capturado
# INFO: 03/23/2019 06:42:51 PM - tweet capturado
# INFO: 03/23/2019 06:42:51 PM - tweet capturado
# INFO: 03/23/2019 06:42:52 PM - tweet capturado
# INFO: 03/23/2019 06:42:52 PM - tweet capturado
# INFO: 03/23/2019 06:42:52 PM - tweet capturado
# INFO: 03/23/2019 06:42:52 PM - tweet capturado
# INFO: 03/23/2019 06:42:53 PM - tweet capturado
# INFO: 03/23/2019 06:42:54 PM - tweet capturado
# INFO: 03/23/2019 06:42:54 PM - tweet capturado
# INFO: 03/23/2019 06:42:55 PM - tweet capturado
# INFO: 03/23/2019 06:42:55 PM - tweet capturado
# INFO: 03/23/2019 06:42:56 PM - tweet capturado
# INFO: 03/23/2019 06:42:58 PM - tweet capturado
# INFO: 03/23/2019 06:42:58 PM - tweet capturado
# INFO: 03/23/2019 06:42:58 PM - tweet capturado
# INFO: 03/23/2019 06:42:58 PM - tweet capturado
# INFO: 03/23/2019 06:42:59 PM - tweet capturado
# INFO: 03/23/2019 06:43:00 PM - tweet capturado
# INFO: 03/23/2019 06:43:01 PM - tweet capturado
# INFO: 03/23/2019 06:43:02 PM - tweet capturado
# INFO: 03/23/2019 06:43:02 PM - tweet capturado
# INFO: 03/23/2019 06:43:03 PM - tweet capturado
# INFO: 03/23/2019 06:43:03 PM - tweet capturado
# INFO: 03/23/2019 06:43:05 PM - tweet capturado
# INFO: 03/23/2019 06:43:05 PM - tweet capturado
# INFO: 03/23/2019 06:43:06 PM - tweet capturado
# INFO: 03/23/2019 06:43:06 PM - tweet capturado
# INFO: 03/23/2019 06:43:06 PM - tweet capturado
# INFO: 03/23/2019 06:43:07 PM - tweet capturado
# INFO: 03/23/2019 06:43:07 PM - tweet capturado
# INFO: 03/23/2019 06:43:07 PM - tweet capturado
# INFO: 03/23/2019 06:43:08 PM - tweet capturado
# INFO: 03/23/2019 06:43:08 PM - tweet capturado
# INFO: 03/23/2019 06:43:09 PM - tweet capturado
# INFO: 03/23/2019 06:43:11 PM - tweet capturado
# INFO: 03/23/2019 06:43:11 PM - tweet capturado
# INFO: 03/23/2019 06:43:11 PM - tweet capturado
# INFO: 03/23/2019 06:43:12 PM - tweet capturado
# INFO: 03/23/2019 06:43:12 PM - tweet capturado
# INFO: 03/23/2019 06:43:15 PM - tweet capturado
# INFO: 03/23/2019 06:43:15 PM - tweet capturado
# INFO: 03/23/2019 06:43:15 PM - tweet capturado
# INFO: 03/23/2019 06:43:15 PM - tweet capturado
# INFO: 03/23/2019 06:43:15 PM - tweet capturado
# INFO: 03/23/2019 06:43:16 PM - tweet capturado
# INFO: 03/23/2019 06:43:17 PM - tweet capturado
# INFO: 03/23/2019 06:43:18 PM - tweet capturado
# INFO: 03/23/2019 06:43:18 PM - tweet capturado
# INFO: 03/23/2019 06:43:18 PM - tweet capturado
# INFO: 03/23/2019 06:43:18 PM - tweet capturado
# INFO: 03/23/2019 06:43:18 PM - tweet capturado
# INFO: 03/23/2019 06:43:19 PM - tweet capturado
# INFO: 03/23/2019 06:43:19 PM - tweet capturado
# INFO: 03/23/2019 06:43:20 PM - tweet capturado
# INFO: 03/23/2019 06:43:21 PM - tweet capturado
# INFO: 03/23/2019 06:43:22 PM - tweet capturado
# INFO: 03/23/2019 06:43:24 PM - tweet capturado
# INFO: 03/23/2019 06:43:25 PM - tweet capturado
# INFO: 03/23/2019 06:43:27 PM - tweet capturado
# INFO: 03/23/2019 06:43:28 PM - tweet capturado
# INFO: 03/23/2019 06:43:28 PM - tweet capturado
# INFO: 03/23/2019 06:43:28 PM - tweet capturado
# INFO: 03/23/2019 06:43:28 PM - tweet capturado
# INFO: 03/23/2019 06:43:28 PM - tweet capturado
# INFO: 03/23/2019 06:43:29 PM - tweet capturado
# INFO: 03/23/2019 06:43:31 PM - tweet capturado
# INFO: 03/23/2019 06:43:31 PM - tweet capturado
# INFO: 03/23/2019 06:43:32 PM - tweet capturado
# INFO: 03/23/2019 06:43:34 PM - tweet capturado
# INFO: 03/23/2019 06:43:34 PM - tweet capturado
# INFO: 03/23/2019 06:43:34 PM - tweet capturado
# INFO: 03/23/2019 06:43:36 PM - tweet capturado
# INFO: 03/23/2019 06:43:36 PM - tweet capturado
# INFO: 03/23/2019 06:43:37 PM - tweet capturado
# INFO: 03/23/2019 06:43:39 PM - tweet capturado
# INFO: 03/23/2019 06:43:39 PM - tweet capturado
# INFO: 03/23/2019 06:43:40 PM - tweet capturado
# INFO: 03/23/2019 06:43:40 PM - tweet capturado
# INFO: 03/23/2019 06:43:40 PM - tweet capturado
# INFO: 03/23/2019 06:43:40 PM - tweet capturado
# INFO: 03/23/2019 06:43:41 PM - tweet capturado
# INFO: 03/23/2019 06:43:41 PM - tweet capturado
# INFO: 03/23/2019 06:43:42 PM - tweet capturado
# INFO: 03/23/2019 06:43:42 PM - tweet capturado
# INFO: 03/23/2019 06:43:43 PM - tweet capturado
# INFO: 03/23/2019 06:43:45 PM - tweet capturado
# INFO: 03/23/2019 06:43:47 PM - tweet capturado
# INFO: 03/23/2019 06:43:48 PM - tweet capturado
# INFO: 03/23/2019 06:43:48 PM - tweet capturado
# INFO: 03/23/2019 06:43:49 PM - tweet capturado
# INFO: 03/23/2019 06:43:51 PM - tweet capturado
# INFO: 03/23/2019 06:43:51 PM - tweet capturado
# INFO: 03/23/2019 06:43:51 PM - tweet capturado
# INFO: 03/23/2019 06:43:52 PM - tweet capturado
# INFO: 03/23/2019 06:43:52 PM - tweet capturado
# INFO: 03/23/2019 06:43:52 PM - tweet capturado
# INFO: 03/23/2019 06:43:53 PM - tweet capturado
# INFO: 03/23/2019 06:43:53 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:43:53 PM - Tiempo transcurrido para obtener 100 tweets: 70.28s
# INFO: 03/23/2019 06:43:55 PM - tweet capturado
# INFO: 03/23/2019 06:43:56 PM - tweet capturado
# INFO: 03/23/2019 06:43:56 PM - tweet capturado
# INFO: 03/23/2019 06:43:56 PM - tweet capturado
# INFO: 03/23/2019 06:43:57 PM - tweet capturado
# INFO: 03/23/2019 06:43:58 PM - tweet capturado
# INFO: 03/23/2019 06:43:58 PM - tweet capturado
# INFO: 03/23/2019 06:43:58 PM - tweet capturado
# INFO: 03/23/2019 06:43:58 PM - tweet capturado
# INFO: 03/23/2019 06:43:59 PM - tweet capturado
# INFO: 03/23/2019 06:44:00 PM - tweet capturado
# INFO: 03/23/2019 06:44:01 PM - tweet capturado
# INFO: 03/23/2019 06:44:01 PM - tweet capturado
# INFO: 03/23/2019 06:44:03 PM - tweet capturado
# INFO: 03/23/2019 06:44:04 PM - tweet capturado
# INFO: 03/23/2019 06:44:04 PM - tweet capturado
# INFO: 03/23/2019 06:44:05 PM - tweet capturado
# INFO: 03/23/2019 06:44:05 PM - tweet capturado
# INFO: 03/23/2019 06:44:08 PM - tweet capturado
# INFO: 03/23/2019 06:44:08 PM - tweet capturado
# INFO: 03/23/2019 06:44:09 PM - tweet capturado
# INFO: 03/23/2019 06:44:10 PM - tweet capturado
# INFO: 03/23/2019 06:44:11 PM - tweet capturado
# INFO: 03/23/2019 06:44:12 PM - tweet capturado
# INFO: 03/23/2019 06:44:12 PM - tweet capturado
# INFO: 03/23/2019 06:44:12 PM - tweet capturado
# INFO: 03/23/2019 06:44:12 PM - tweet capturado
# INFO: 03/23/2019 06:44:13 PM - tweet capturado
# INFO: 03/23/2019 06:44:14 PM - tweet capturado
# INFO: 03/23/2019 06:44:14 PM - tweet capturado
# INFO: 03/23/2019 06:44:15 PM - tweet capturado
# INFO: 03/23/2019 06:44:16 PM - tweet capturado
# INFO: 03/23/2019 06:44:17 PM - tweet capturado
# INFO: 03/23/2019 06:44:17 PM - tweet capturado
# INFO: 03/23/2019 06:44:17 PM - tweet capturado
# INFO: 03/23/2019 06:44:19 PM - tweet capturado
# INFO: 03/23/2019 06:44:20 PM - tweet capturado
# INFO: 03/23/2019 06:44:21 PM - tweet capturado
# INFO: 03/23/2019 06:44:21 PM - tweet capturado
# INFO: 03/23/2019 06:44:21 PM - tweet capturado
# INFO: 03/23/2019 06:44:21 PM - tweet capturado
# INFO: 03/23/2019 06:44:22 PM - tweet capturado
# INFO: 03/23/2019 06:44:25 PM - tweet capturado
# INFO: 03/23/2019 06:44:25 PM - tweet capturado
# INFO: 03/23/2019 06:44:25 PM - tweet capturado
# INFO: 03/23/2019 06:44:27 PM - tweet capturado
# INFO: 03/23/2019 06:44:28 PM - tweet capturado
# INFO: 03/23/2019 06:44:29 PM - tweet capturado
# INFO: 03/23/2019 06:44:30 PM - tweet capturado
# INFO: 03/23/2019 06:44:32 PM - tweet capturado
# INFO: 03/23/2019 06:44:33 PM - tweet capturado
# INFO: 03/23/2019 06:44:34 PM - tweet capturado
# INFO: 03/23/2019 06:44:34 PM - tweet capturado
# INFO: 03/23/2019 06:44:35 PM - tweet capturado
# INFO: 03/23/2019 06:44:35 PM - tweet capturado
# INFO: 03/23/2019 06:44:36 PM - tweet capturado
# INFO: 03/23/2019 06:44:37 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:38 PM - tweet capturado
# INFO: 03/23/2019 06:44:39 PM - tweet capturado
# INFO: 03/23/2019 06:44:40 PM - tweet capturado
# INFO: 03/23/2019 06:44:40 PM - tweet capturado
# INFO: 03/23/2019 06:44:41 PM - tweet capturado
# INFO: 03/23/2019 06:44:42 PM - tweet capturado
# INFO: 03/23/2019 06:44:42 PM - tweet capturado
# INFO: 03/23/2019 06:44:44 PM - tweet capturado
# INFO: 03/23/2019 06:44:48 PM - tweet capturado
# INFO: 03/23/2019 06:44:48 PM - tweet capturado
# INFO: 03/23/2019 06:44:48 PM - tweet capturado
# INFO: 03/23/2019 06:44:49 PM - tweet capturado
# INFO: 03/23/2019 06:44:50 PM - tweet capturado
# INFO: 03/23/2019 06:44:50 PM - tweet capturado
# INFO: 03/23/2019 06:44:50 PM - tweet capturado
# INFO: 03/23/2019 06:44:52 PM - tweet capturado
# INFO: 03/23/2019 06:44:53 PM - tweet capturado
# INFO: 03/23/2019 06:44:53 PM - tweet capturado
# INFO: 03/23/2019 06:44:54 PM - tweet capturado
# INFO: 03/23/2019 06:44:54 PM - tweet capturado
# INFO: 03/23/2019 06:44:56 PM - tweet capturado
# INFO: 03/23/2019 06:44:56 PM - tweet capturado
# INFO: 03/23/2019 06:44:56 PM - tweet capturado
# INFO: 03/23/2019 06:44:58 PM - tweet capturado
# INFO: 03/23/2019 06:44:59 PM - tweet capturado
# INFO: 03/23/2019 06:45:00 PM - tweet capturado
# INFO: 03/23/2019 06:45:02 PM - tweet capturado
# INFO: 03/23/2019 06:45:03 PM - tweet capturado
# INFO: 03/23/2019 06:45:04 PM - tweet capturado
# INFO: 03/23/2019 06:45:04 PM - tweet capturado
# INFO: 03/23/2019 06:45:04 PM - tweet capturado
# INFO: 03/23/2019 06:45:05 PM - tweet capturado
# INFO: 03/23/2019 06:45:05 PM - tweet capturado
# INFO: 03/23/2019 06:45:05 PM - tweet capturado
# INFO: 03/23/2019 06:45:06 PM - tweet capturado
# INFO: 03/23/2019 06:45:07 PM - tweet capturado
# INFO: 03/23/2019 06:45:07 PM - tweet capturado
# INFO: 03/23/2019 06:45:08 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:45:08 PM - Tiempo transcurrido para obtener 100 tweets: 75.26s
# INFO: 03/23/2019 06:45:08 PM - tweet capturado
# INFO: 03/23/2019 06:45:11 PM - tweet capturado
# INFO: 03/23/2019 06:45:13 PM - tweet capturado
# INFO: 03/23/2019 06:45:13 PM - tweet capturado
# INFO: 03/23/2019 06:45:13 PM - tweet capturado
# INFO: 03/23/2019 06:45:15 PM - tweet capturado
# INFO: 03/23/2019 06:45:15 PM - tweet capturado
# INFO: 03/23/2019 06:45:16 PM - tweet capturado
# INFO: 03/23/2019 06:45:16 PM - tweet capturado
# INFO: 03/23/2019 06:45:17 PM - tweet capturado
# INFO: 03/23/2019 06:45:18 PM - tweet capturado
# INFO: 03/23/2019 06:45:18 PM - tweet capturado
# INFO: 03/23/2019 06:45:19 PM - tweet capturado
# INFO: 03/23/2019 06:45:19 PM - tweet capturado
# INFO: 03/23/2019 06:45:19 PM - tweet capturado
# INFO: 03/23/2019 06:45:20 PM - tweet capturado
# INFO: 03/23/2019 06:45:21 PM - tweet capturado
# INFO: 03/23/2019 06:45:22 PM - tweet capturado
# INFO: 03/23/2019 06:45:23 PM - tweet capturado
# INFO: 03/23/2019 06:45:23 PM - tweet capturado
# INFO: 03/23/2019 06:45:24 PM - tweet capturado
# INFO: 03/23/2019 06:45:26 PM - tweet capturado
# INFO: 03/23/2019 06:45:28 PM - tweet capturado
# INFO: 03/23/2019 06:45:28 PM - tweet capturado
# INFO: 03/23/2019 06:45:29 PM - tweet capturado
# INFO: 03/23/2019 06:45:32 PM - tweet capturado
# INFO: 03/23/2019 06:45:32 PM - tweet capturado
# INFO: 03/23/2019 06:45:32 PM - tweet capturado
# INFO: 03/23/2019 06:45:34 PM - tweet capturado
# INFO: 03/23/2019 06:45:34 PM - tweet capturado
# INFO: 03/23/2019 06:45:35 PM - tweet capturado
# INFO: 03/23/2019 06:45:36 PM - tweet capturado
# INFO: 03/23/2019 06:45:36 PM - tweet capturado
# INFO: 03/23/2019 06:45:38 PM - tweet capturado
# INFO: 03/23/2019 06:45:38 PM - tweet capturado
# INFO: 03/23/2019 06:45:40 PM - tweet capturado
# INFO: 03/23/2019 06:45:40 PM - tweet capturado
# INFO: 03/23/2019 06:45:40 PM - tweet capturado
# INFO: 03/23/2019 06:45:40 PM - tweet capturado
# INFO: 03/23/2019 06:45:40 PM - tweet capturado
# INFO: 03/23/2019 06:45:41 PM - tweet capturado
# INFO: 03/23/2019 06:45:42 PM - tweet capturado
# INFO: 03/23/2019 06:45:42 PM - tweet capturado
# INFO: 03/23/2019 06:45:43 PM - tweet capturado
# INFO: 03/23/2019 06:45:43 PM - tweet capturado
# INFO: 03/23/2019 06:45:43 PM - tweet capturado
# INFO: 03/23/2019 06:45:43 PM - tweet capturado
# INFO: 03/23/2019 06:45:44 PM - tweet capturado
# INFO: 03/23/2019 06:45:45 PM - tweet capturado
# INFO: 03/23/2019 06:45:47 PM - tweet capturado
# INFO: 03/23/2019 06:45:47 PM - tweet capturado
# INFO: 03/23/2019 06:45:48 PM - tweet capturado
# INFO: 03/23/2019 06:45:48 PM - tweet capturado
# INFO: 03/23/2019 06:45:48 PM - tweet capturado
# INFO: 03/23/2019 06:45:49 PM - tweet capturado
# INFO: 03/23/2019 06:45:49 PM - tweet capturado
# INFO: 03/23/2019 06:45:50 PM - tweet capturado
# INFO: 03/23/2019 06:45:53 PM - tweet capturado
# INFO: 03/23/2019 06:45:53 PM - tweet capturado
# INFO: 03/23/2019 06:45:55 PM - tweet capturado
# INFO: 03/23/2019 06:45:56 PM - tweet capturado
# INFO: 03/23/2019 06:45:56 PM - tweet capturado
# INFO: 03/23/2019 06:45:57 PM - tweet capturado
# INFO: 03/23/2019 06:45:57 PM - tweet capturado
# INFO: 03/23/2019 06:45:57 PM - tweet capturado
# INFO: 03/23/2019 06:46:00 PM - tweet capturado
# INFO: 03/23/2019 06:46:02 PM - tweet capturado
# INFO: 03/23/2019 06:46:02 PM - tweet capturado
# INFO: 03/23/2019 06:46:04 PM - tweet capturado
# INFO: 03/23/2019 06:46:05 PM - tweet capturado
# INFO: 03/23/2019 06:46:05 PM - tweet capturado
# INFO: 03/23/2019 06:46:06 PM - tweet capturado
# INFO: 03/23/2019 06:46:06 PM - tweet capturado
# INFO: 03/23/2019 06:46:06 PM - tweet capturado
# INFO: 03/23/2019 06:46:07 PM - tweet capturado
# INFO: 03/23/2019 06:46:08 PM - tweet capturado
# INFO: 03/23/2019 06:46:08 PM - tweet capturado
# INFO: 03/23/2019 06:46:09 PM - tweet capturado
# INFO: 03/23/2019 06:46:10 PM - tweet capturado
# INFO: 03/23/2019 06:46:10 PM - tweet capturado
# INFO: 03/23/2019 06:46:11 PM - tweet capturado
# INFO: 03/23/2019 06:46:11 PM - tweet capturado
# INFO: 03/23/2019 06:46:13 PM - tweet capturado
# INFO: 03/23/2019 06:46:13 PM - tweet capturado
# INFO: 03/23/2019 06:46:15 PM - tweet capturado
# INFO: 03/23/2019 06:46:16 PM - tweet capturado
# INFO: 03/23/2019 06:46:17 PM - tweet capturado
# INFO: 03/23/2019 06:46:19 PM - tweet capturado
# INFO: 03/23/2019 06:46:20 PM - tweet capturado
# INFO: 03/23/2019 06:46:21 PM - tweet capturado
# INFO: 03/23/2019 06:46:21 PM - tweet capturado
# INFO: 03/23/2019 06:46:23 PM - tweet capturado
# INFO: 03/23/2019 06:46:24 PM - tweet capturado
# INFO: 03/23/2019 06:46:24 PM - tweet capturado
# INFO: 03/23/2019 06:46:26 PM - tweet capturado
# INFO: 03/23/2019 06:46:27 PM - tweet capturado
# INFO: 03/23/2019 06:46:27 PM - tweet capturado
# INFO: 03/23/2019 06:46:28 PM - tweet capturado
# INFO: 03/23/2019 06:46:28 PM - tweet capturado
# INFO: 03/23/2019 06:46:29 PM - tweet capturado
# INFO: 03/23/2019 06:46:29 PM - tweet capturado
# INFO: 03/23/2019 06:46:29 PM - ------- Data dumped -------
# INFO: 03/23/2019 06:46:29 PM - Tiempo transcurrido para obtener 100 tweets: 81.43s
# INFO: 03/23/2019 06:46:30 PM - tweet capturado
# INFO: 03/23/2019 06:46:30 PM - tweet capturado
# INFO: 03/23/2019 06:46:30 PM - tweet capturado
# INFO: 03/23/2019 06:46:31 PM - tweet capturado
# INFO: 03/23/2019 06:46:31 PM - tweet capturado
# INFO: 03/23/2019 06:46:32 PM - tweet capturado
# INFO: 03/23/2019 06:46:32 PM - tweet capturado
# INFO: 03/23/2019 06:46:32 PM - tweet capturado
# INFO: 03/23/2019 06:46:34 PM - tweet capturado
# INFO: 03/23/2019 06:46:34 PM - tweet capturado
# INFO: 03/23/2019 06:46:35 PM - tweet capturado
# INFO: 03/23/2019 06:46:35 PM - tweet capturado
# INFO: 03/23/2019 06:46:35 PM - tweet capturado
# INFO: 03/23/2019 06:46:35 PM - tweet capturado
# INFO: 03/23/2019 06:46:37 PM - tweet capturado
# INFO: 03/23/2019 06:46:37 PM - tweet capturado
# INFO: 03/23/2019 06:46:37 PM - tweet capturado
# INFO: 03/23/2019 06:46:37 PM - tweet capturado
# INFO: 03/23/2019 06:46:37 PM - tweet capturado
# INFO: 03/23/2019 06:46:38 PM - tweet capturado
# INFO: 03/23/2019 06:46:38 PM - tweet capturado
# INFO: 03/23/2019 06:46:39 PM - tweet capturado
# INFO: 03/23/2019 06:46:39 PM - tweet capturado
# INFO: 03/23/2019 06:46:39 PM - tweet capturado
# INFO: 03/23/2019 06:46:41 PM - tweet capturado
# INFO: 03/23/2019 06:46:41 PM - tweet capturado
# INFO: 03/23/2019 06:46:41 PM - tweet capturado
# INFO: 03/23/2019 06:46:43 PM - tweet capturado
# INFO: 03/23/2019 06:46:43 PM - tweet capturado
# INFO: 03/23/2019 06:46:44 PM - tweet capturado
# INFO: 03/23/2019 06:46:44 PM - tweet capturado
# INFO: 03/23/2019 06:46:45 PM - tweet capturado
# INFO: 03/23/2019 06:46:45 PM - tweet capturado
# INFO: 03/23/2019 06:46:46 PM - tweet capturado
# INFO: 03/23/2019 06:46:46 PM - tweet capturado
# INFO: 03/23/2019 06:46:47 PM - tweet capturado
# INFO: 03/23/2019 06:46:47 PM - tweet capturado
# INFO: 03/23/2019 06:46:48 PM - tweet capturado
# INFO: 03/23/2019 06:46:48 PM - tweet capturado
# INFO: 03/23/2019 06:46:48 PM - tweet capturado
# INFO: 03/23/2019 06:46:48 PM - tweet capturado
# INFO: 03/23/2019 06:46:49 PM - tweet capturado
# INFO: 03/23/2019 06:46:51 PM - tweet capturado
# INFO: 03/23/2019 06:46:52 PM - tweet capturado
# INFO: 03/23/2019 06:46:52 PM - tweet capturado
# INFO: 03/23/2019 06:46:52 PM - tweet capturado
# INFO: 03/23/2019 06:46:52 PM - tweet capturado
# INFO: 03/23/2019 06:46:53 PM - tweet capturado
# INFO: 03/23/2019 06:46:54 PM - tweet capturado
# INFO: 03/23/2019 06:46:54 PM - tweet capturado
# INFO: 03/23/2019 06:46:54 PM - tweet capturado
# INFO: 03/23/2019 06:46:55 PM - tweet capturado
# INFO: 03/23/2019 06:46:55 PM - tweet capturado
# INFO: 03/23/2019 06:46:56 PM - tweet capturado
# INFO: 03/23/2019 06:46:57 PM - tweet capturado
# INFO: 03/23/2019 06:46:58 PM - tweet capturado
# INFO: 03/23/2019 06:47:01 PM - tweet capturado
# INFO: 03/23/2019 06:47:01 PM - tweet capturado
# INFO: 03/23/2019 06:47:02 PM - tweet capturado
# INFO: 03/23/2019 06:47:03 PM - tweet capturado
# INFO: 03/23/2019 06:47:06 PM - tweet capturado
# INFO: 03/23/2019 06:47:07 PM - tweet capturado
# INFO: 03/23/2019 06:47:07 PM - tweet capturado
# INFO: 03/23/2019 06:47:08 PM - tweet capturado
# INFO: 03/23/2019 06:47:10 PM - tweet capturado
# INFO: 03/23/2019 06:47:11 PM - tweet capturado
# INFO: 03/23/2019 06:47:11 PM - tweet capturado
# INFO: 03/23/2019 06:47:11 PM - tweet capturado
# INFO: 03/23/2019 06:47:13 PM - tweet capturado
# INFO: 03/23/2019 06:47:14 PM - tweet capturado
# INFO: 03/23/2019 06:47:15 PM - tweet capturado
# INFO: 03/23/2019 06:47:17 PM - tweet capturado
# INFO: 03/23/2019 06:47:19 PM - tweet capturado
# INFO: 03/23/2019 06:47:19 PM - tweet capturado
# INFO: 03/23/2019 06:47:22 PM - tweet capturado
# INFO: 03/23/2019 06:47:22 PM - tweet capturado
# INFO: 03/23/2019 06:47:23 PM - tweet capturado
# INFO: 03/23/2019 06:47:24 PM - tweet capturado
# INFO: 03/23/2019 06:47:25 PM - tweet capturado
# INFO: 03/23/2019 06:47:26 PM - tweet capturado
# INFO: 03/23/2019 06:47:26 PM - tweet capturado
# INFO: 03/23/2019 06:47:27 PM - tweet capturado
# INFO: 03/23/2019 06:47:28 PM - tweet capturado
# INFO: 03/23/2019 06:47:28 PM - tweet capturado
# INFO: 03/23/2019 06:47:30 PM - tweet capturado
# INFO: 03/23/2019 06:47:30 PM - tweet capturado
# INFO: 03/23/2019 06:47:31 PM - tweet capturado
# INFO: 03/23/2019 06:47:31 PM - tweet capturado
# INFO: 03/23/2019 06:47:32 PM - tweet capturado
# INFO: 03/23/2019 06:47:32 PM - tweet capturado
# INFO: 03/23/2019 06:47:33 PM - tweet capturado
# INFO: 03/23/2019 06:47:35 PM - tweet capturado
# INFO: 03/23/2019 06:47:36 PM - tweet capturado
# INFO: 03/23/2019 06:47:37 PM - tweet capturado
# INFO: 03/23/2019 06:47:38 PM - tweet capturado
# INFO: 03/23/2019 06:47:38 PM - tweet capturado
