# %%
from glob import glob
import os
import pandas as pd

# %%
archivos = [os.path.basename(x) for x in glob('./Tweets/*.json')]
archivos = glob('./Tweets/*.json')

# %%
dataframes = []
en_lectura = ""
try:
    for arch in archivos:
        en_estudio = arch
        dataframes.append(pd.read_json(arch))
except:
    print("Error leyendo el archivo " + en_leectura)

# %%
df = pd.concat(dataframes, sort=False)

# %%
df.shape
# Out:
# (1018, 36)

# %%
df.dtypes
# Out:
# contributors                        float64
# coordinates                         float64
# created_at                   datetime64[ns]
# display_text_range                   object
# entities                             object
# extended_entities                    object
# extended_tweet                       object
# favorite_count                        int64
# favorited                              bool
# filter_level                         object
# geo                                 float64
# id                                    int64
# id_str                                int64
# in_reply_to_screen_name              object
# in_reply_to_status_id               float64
# in_reply_to_status_id_str           float64
# in_reply_to_user_id                 float64
# in_reply_to_user_id_str             float64
# is_quote_status                        bool
# lang                                 object
# place                                object
# possibly_sensitive                  float64
# quote_count                           int64
# quoted_status                        object
# quoted_status_id                    float64
# quoted_status_id_str                float64
# quoted_status_permalink              object
# reply_count                           int64
# retweet_count                         int64
# retweeted                              bool
# retweeted_status                     object
# source                               object
# text                                 object
# timestamp_ms                 datetime64[ns]
# truncated                              bool
# user                                 object
# dtype: object

# %%
df[['text','user','retweeted']]
# Out:
#                                                   text  \
# 0    A 15 años de la recuperación de la ESMA, el di...
# 1    @eldestapeweb @Siempre_Ciclon Macri puede esta...
# 2    RT @nelpold: Sudamérica entierra a la Unasur d...
# 3    RT @sergiodwy: Cristobal López está preso, se ...
# 4    RT @BonelliOK: #Encuesta\nSi tuvieras la oport...
# 5    Tiene las piernas hinchadas....Cualquiera conv...
# 6    RT @silviapalmword: O un #HipotecadosUva que l...
# 7    RT @77azulgrana: Siempre, siempre, tenés q ser...
# 8    RT @javiernavia: Así te mienten https://t.co/7...
# 9    RT @jotaalonso: Sábado de sol, familias intent...
# 10   RT @mirif68: NO CREO QUE MANES SE PRESTE A  SU...
# 11   RT @sergiodwy: Cristobal López está preso, se ...
# 12   @diego_melonos @WaltN1981 @GiacoDiego Yo no me...
# 13   RT @LuisGasulla: #24MPorLaMemoria Utilizando a...
# 14   @ECfk2019 @Charoli2015 Ojala sea asi y me disc...
# 15   RT @fargosi: Que raro, el video completo muest...
# 16   RT @BonelliOK: #Encuesta\nSi tuvieras la oport...
# 17   RT @Manu_Auge: @GallitoGodoy Yo no voy a pedir...
# 18   RT @LuisGasulla: #24MPorLaMemoria Utilizando a...
# 19   RT @VerbitskyH: Entrevista a Rodolfo Daer por ...
# 20   RT @fargosi: Que raro, el video completo muest...
# 21   RT @LaBelgrana: Dice Espert que para cambiar e...
# 22   RT @jotaalonso: Sábado de sol, familias intent...
# 23   RT @dsantoro59: Manzanares reveló que el valet...
# 24   RT @jotaalonso: La tapa de El País augura con ...
# 25   RT @atlanticsurff: ✔️Perfil: Otro mal momento ...
# 26   RT @AlfredoDarrigo: El desbarranque de Andahaz...
# 27   RT @BonelliOK: #Encuesta\nSi tuvieras la oport...
# 28   RT @LuisGasulla: Háganse cargo de Milani. Aním...
# 29   RT @guillotina755: @sbatakis @Cascotealambra1 ...
# ..                                                 ...
# 71   RT @malave_nancy: @AntEsRiv @raul_lucarini @da...
# 72   RT @jcoulon: Prosur se divide tareas.\nPiñera ...
# 73   RT @UniCiudadanaAR: A 15 años de la recuperaci...
# 74   RT @infobae: Con la presencia de Alicia Kirchn...
# 75   RT @mmilena64: #QueVuelvaElla y lo va a poder ...
# 76   RT @Ale_Bodart: Desde el @MSTargentina repudia...
# 77   RT @pulsionparcial: Le hacen la V peronista a ...
# 78   RT @rolandosantoro6: Si Cristina Kirchner va p...
# 79   RT @FernandezAnibal: Fantino pegó un volantazo...
# 80   RT @robdnavarro: Guillermo Moreno: "Roberto La...
# 81   RT @BonelliOK: #Encuesta\nSi tuvieras la oport...
# 82   RT @atilioboron: #NoAlPatentamientoDeSemillas ...
# 83   @animalesoficial @agencialavieja @AmericaTV SO...
# 84   RT @gebanzas: @LongobardiM @diegoleuco @andaha...
# 85   RT @jlespert: Ni Macri, Ni Cristina, Espert pa...
# 86   RT @AngelicaLagunas: La policía ingresó al loc...
# 87   RT @QCastana: Exclusivo: las tres explosivas d...
# 88   RT @MargaWirkierman: Volvimos al mundo como qu...
# 89   RT @agustinvidal5: Cierra el shopping de Villa...
# 90   RT @atilioboron: #NoAlPatentamientoDeSemillas ...
# 91   RT @emigbusquet: Señor y señora ama de casa. N...
# 92   Resultó que Moreno es más pelotudo de lo que c...
# 93   RT @marineroderadio: Parece que la cosa es así...
# 94   RT @FebosAnalytics: Si Máximo Kirchner se post...
# 95   RT @Aabadonh: Alrededor de Lavagna se van ubic...
# 96   RT @edgerome: Baby Echecopar la tiene clara.  ...
# 97   RT @jotaalonso: Cada una de las tapas de los g...
# 98   RT @EduInversor: 📣 Nuevo espaldarazo de EE.UU....
# 99   Que carajo esta pasando con la leche entera? E...
# 100  RT @Ale_Bodart: Desde el @MSTargentina repudia...
#
#                                                   user  retweeted
# 0    {'id': 76363710, 'id_str': '76363710', 'name':...      False
# 1    {'id': 2731989308, 'id_str': '2731989308', 'na...      False
# 2    {'id': 163256228, 'id_str': '163256228', 'name...      False
# 3    {'id': 2756454819, 'id_str': '2756454819', 'na...      False
# 4    {'id': 155395750, 'id_str': '155395750', 'name...      False
# 5    {'id': 1713964237, 'id_str': '1713964237', 'na...      False
# 6    {'id': 2786038569, 'id_str': '2786038569', 'na...      False
# 7    {'id': 2456349795, 'id_str': '2456349795', 'na...      False
# 8    {'id': 151660880, 'id_str': '151660880', 'name...      False
# 9    {'id': 3371658088, 'id_str': '3371658088', 'na...      False
# 10   {'id': 3053046383, 'id_str': '3053046383', 'na...      False
# 11   {'id': 1041039133026729985, 'id_str': '1041039...      False
# 12   {'id': 151649219, 'id_str': '151649219', 'name...      False
# 13   {'id': 190767834, 'id_str': '190767834', 'name...      False
# 14   {'id': 999665179334991878, 'id_str': '99966517...      False
# 15   {'id': 3326050276, 'id_str': '3326050276', 'na...      False
# 16   {'id': 373903723, 'id_str': '373903723', 'name...      False
# 17   {'id': 1001265770163302406, 'id_str': '1001265...      False
# 18   {'id': 186328651, 'id_str': '186328651', 'name...      False
# 19   {'id': 143685841, 'id_str': '143685841', 'name...      False
# 20   {'id': 575649871, 'id_str': '575649871', 'name...      False
# 21   {'id': 186503168, 'id_str': '186503168', 'name...      False
# 22   {'id': 2684101605, 'id_str': '2684101605', 'na...      False
# 23   {'id': 741062399143346176, 'id_str': '74106239...      False
# 24   {'id': 800050595503702018, 'id_str': '80005059...      False
# 25   {'id': 1458151052, 'id_str': '1458151052', 'na...      False
# 26   {'id': 1112220727, 'id_str': '1112220727', 'na...      False
# 27   {'id': 175427609, 'id_str': '175427609', 'name...      False
# 28   {'id': 1265179363, 'id_str': '1265179363', 'na...      False
# 29   {'id': 4160782817, 'id_str': '4160782817', 'na...      False
# ..                                                 ...        ...
# 71   {'id': 3434404877, 'id_str': '3434404877', 'na...      False
# 72   {'id': 129692242, 'id_str': '129692242', 'name...      False
# 73   {'id': 1475719610, 'id_str': '1475719610', 'na...      False
# 74   {'id': 3930183867, 'id_str': '3930183867', 'na...      False
# 75   {'id': 967831124989931522, 'id_str': '96783112...      False
# 76   {'id': 1222941859, 'id_str': '1222941859', 'na...      False
# 77   {'id': 108204909, 'id_str': '108204909', 'name...      False
# 78   {'id': 1384491782, 'id_str': '1384491782', 'na...      False
# 79   {'id': 4193307977, 'id_str': '4193307977', 'na...      False
# 80   {'id': 1475719610, 'id_str': '1475719610', 'na...      False
# 81   {'id': 1401108176, 'id_str': '1401108176', 'na...      False
# 82   {'id': 844560350, 'id_str': '844560350', 'name...      False
# 83   {'id': 1055940959874236418, 'id_str': '1055940...      False
# 84   {'id': 182582501, 'id_str': '182582501', 'name...      False
# 85   {'id': 735140807137755136, 'id_str': '73514080...      False
# 86   {'id': 1663667888, 'id_str': '1663667888', 'na...      False
# 87   {'id': 164277411, 'id_str': '164277411', 'name...      False
# 88   {'id': 714028400927748096, 'id_str': '71402840...      False
# 89   {'id': 1106416909933793280, 'id_str': '1106416...      False
# 90   {'id': 463311030, 'id_str': '463311030', 'name...      False
# 91   {'id': 1642897352, 'id_str': '1642897352', 'na...      False
# 92   {'id': 1018465662, 'id_str': '1018465662', 'na...      False
# 93   {'id': 285866769, 'id_str': '285866769', 'name...      False
# 94   {'id': 713375551046742016, 'id_str': '71337555...      False
# 95   {'id': 718402183931281409, 'id_str': '71840218...      False
# 96   {'id': 1052022622790307841, 'id_str': '1052022...      False
# 97   {'id': 157523545, 'id_str': '157523545', 'name...      False
# 98   {'id': 247929216, 'id_str': '247929216', 'name...      False
# 99   {'id': 909260043727638529, 'id_str': '90926004...      False
# 100  {'id': 981531159531347968, 'id_str': '98153115...      False
#
# [1018 rows x 3 columns]
